# %% [markdown]
# # Step 1: Data Loading and Initial Exploration

# %%
import pandas as pd

# Load the dataset
file_path = '/Users/Audrey/Desktop/megastore_dataset.csv'
df = pd.read_csv(file_path)

# Check the first few rows of the dataset
print(df.head())

# Check for missing values and data types
print(df.info())
# Out:
#    OrderID  CustomerID                         ProductName  Quantity  \
# 0   536370     12583.0         INFLATABLE POLITICAL GLOBE         48
# 1   536370     12583.0      SET2 RED RETROSPOT TEA TOWELS         18
# 2   536370     12583.0     PANDA AND BUNNIES STICKER SHEET        12
# 3   536370     12583.0       RED TOADSTOOL LED NIGHT LIGHT        24
# 4   536370     12583.0  VINTAGE HEADS AND TAILS CARD GAME         24
#
#       InvoiceDate  UnitPrice  TotalCost         Country Discount_Applied  \
# 0  12/1/2010 8:45      $0.85     $40.80   United States              Yes
# 1  12/1/2010 8:45      $2.95     $53.10   United States              Yes
# 2  12/1/2010 8:45      $0.85     $10.20   United States              Yes
# 3  12/1/2010 8:45      $1.65     $39.60   United States              Yes
# 4  12/1/2010 8:45      $1.25     $30.00   United States              Yes
#
#   Order Priority     Region    Segment ExpeditedShipping PaymentMethod  \
# 0           High  Northeast  Corporate               Yes   Credit Card
# 1           High  Northeast  Corporate               Yes   Credit Card
# 2           High  Northeast  Corporate               Yes   Credit Card
# 3           High  Northeast  Corporate               Yes   Credit Card
# 4           High  Northeast  Corporate               Yes   Credit Card
#
#   CustomerRewardsMember
# 0                   Yes
# 1                   Yes
# 2                   Yes
# 3                   Yes
# 4                   Yes
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8234 entries, 0 to 8233
# Data columns (total 15 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   OrderID                8234 non-null   int64
#  1   CustomerID             8168 non-null   float64
#  2   ProductName            8234 non-null   object
#  3   Quantity               8234 non-null   int64
#  4   InvoiceDate            8234 non-null   object
#  5    UnitPrice             8234 non-null   object
#  6   TotalCost              8234 non-null   object
#  7   Country                8234 non-null   object
#  8   Discount_Applied       40 non-null     object
#  9   Order Priority         8234 non-null   object
#  10  Region                 8234 non-null   object
#  11  Segment                8234 non-null   object
#  12  ExpeditedShipping      8234 non-null   object
#  13  PaymentMethod          8234 non-null   object
#  14  CustomerRewardsMember  8234 non-null   object
# dtypes: float64(1), int64(2), object(12)
# memory usage: 965.1+ KB
# None

# %% [markdown]
# # Step 2: Data Wrangling (Selecting and Encoding Categorical Variables)

# %% [markdown]
# - Ordinal variables (Order Priority, CustomerRewardsMember)
# - Nominal variables (PaymentMethod, Country)

# %%
from sklearn.preprocessing import LabelEncoder

# Ordinal encoding for 'Order Priority'
order_priority_mapping = {'Low': 1, 'Medium': 2, 'High': 3, 'Critical': 4}
df['Order Priority'] = df['Order Priority'].map(order_priority_mapping)

# Label encoding for 'Customer Rewards Member'
label_encoder = LabelEncoder()
df['CustomerRewardsMember'] = label_encoder.fit_transform(df['CustomerRewardsMember'])

# Print the encoded variables
print(df[['Order Priority', 'CustomerRewardsMember']].head())
# Out:
#    Order Priority  CustomerRewardsMember
# 0               3                      1
# 1               3                      1
# 2               3                      1
# 3               3                      1
# 4               3                      1

# %% [markdown]
# ## Encoding Nominal Variables

# %%
# One-hot encoding for 'Payment Method' and 'Country'
df_encoded = pd.get_dummies(df, columns=['PaymentMethod', 'Country'], drop_first=True)

# Print the first few rows after encoding
print(df_encoded.head())
# Out:
#    OrderID  CustomerID                         ProductName  Quantity  \
# 0   536370     12583.0         INFLATABLE POLITICAL GLOBE         48
# 1   536370     12583.0      SET2 RED RETROSPOT TEA TOWELS         18
# 2   536370     12583.0     PANDA AND BUNNIES STICKER SHEET        12
# 3   536370     12583.0       RED TOADSTOOL LED NIGHT LIGHT        24
# 4   536370     12583.0  VINTAGE HEADS AND TAILS CARD GAME         24
#
#       InvoiceDate  UnitPrice  TotalCost  Discount_Applied  Order Priority  \
# 0  12/1/2010 8:45      $0.85     $40.80               Yes               3
# 1  12/1/2010 8:45      $2.95     $53.10               Yes               3
# 2  12/1/2010 8:45      $0.85     $10.20               Yes               3
# 3  12/1/2010 8:45      $1.65     $39.60               Yes               3
# 4  12/1/2010 8:45      $1.25     $30.00               Yes               3
#
#       Region    Segment ExpeditedShipping  CustomerRewardsMember  \
# 0  Northeast  Corporate               Yes                      1
# 1  Northeast  Corporate               Yes                      1
# 2  Northeast  Corporate               Yes                      1
# 3  Northeast  Corporate               Yes                      1
# 4  Northeast  Corporate               Yes                      1
#
#    PaymentMethod_PayPal
# 0                 False
# 1                 False
# 2                 False
# 3                 False
# 4                 False

# %% [markdown]
# # Step 3: Transactionalizing Data for Market Basket Analysis

# %%
# Group data by 'OrderID' and 'ProductName'
df_grouped = df.groupby(['OrderID', 'ProductName'])['Quantity'].sum().unstack().reset_index().fillna(0)

# Convert quantities to binary (0 or 1) using 'map' as per the warning
df_grouped.set_index('OrderID', inplace=True)
df_grouped = df_grouped.map(lambda x: 1 if x > 0 else 0)

# Print the first few rows of transactional data
print(df_grouped.head())
# Out:
# ProductName   50S CHRISTMAS GIFT BAG LARGE   DOLLY GIRL BEAKER  \
# OrderID
# 536370                                   0                   0
# 536852                                   0                   0
# 536974                                   0                   0
# 537065                                   0                   0
# 537463                                   0                   0
#
# ProductName   I LOVE LONDON MINI BACKPACK   NINE DRAWER OFFICE TIDY  \
# OrderID
# 536370                                  0                         0
# 536852                                  0                         0
# 536974                                  0                         0
# 537065                                  0                         0
# 537463                                  0                         0
#
# ProductName   SET 2 TEA TOWELS I LOVE LONDON    SPACEBOY BABY GIFT SET  \
# OrderID
# 536370                                      0                        0
# 536852                                      0                        0
# 536974                                      0                        0
# 537065                                      0                        0
# 537463                                      0                        0
#
# ProductName   TRELLIS COAT RACK  10 COLOUR SPACEBOY PEN  \
# OrderID
# 536370                        0                       0
# 536852                        0                       0
# 536974                        0                       0
# 537065                        0                       0
# 537463                        0                       0
#
# ProductName  12 COLOURED PARTY BALLOONS  12 EGG HOUSE PAINTED WOOD  ...  \
# OrderID                                                             ...
# 536370                                0                          0  ...
# 536852                                0                          0  ...
# 536974                                0                          0  ...
# 537065                                0                          0  ...
# 537463                                0                          0  ...
#
# ProductName  WRAP VINTAGE PETALS  DESIGN  YELLOW COAT RACK PARIS FASHION  \
# OrderID
# 536370                                 0                               0
# 536852                                 0                               0
# 536974                                 0                               0
# 537065                                 0                               0
# 537463                                 0                               0
#
# ProductName  YELLOW GIANT GARDEN THERMOMETER  YELLOW SHARK HELICOPTER  \
# OrderID
# 536370                                     0                        0
# 536852                                     0                        0
# 536974                                     0                        0
# 537065                                     0                        0
# 537463                                     0                        0
#
# ProductName  ZINC  STAR TLIGHT HOLDER   ZINC FOLKART SLEIGH BELLS  \
# OrderID
# 536370                               0                          0
# 536852                               0                          0
# 536974                               0                          0
# 537065                               0                          0
# 537463                               0                          0
#
# ProductName  ZINC HERB GARDEN CONTAINER  ZINC METAL HEART DECORATION  \
# OrderID
# 536370                                0                            0
# 536852                                0                            0
# 536974                                0                            0
# 537065                                0                            0
# 537463                                0                            0
#
# ProductName  ZINC TLIGHT HOLDER STAR LARGE  ZINC TLIGHT HOLDER STARS SMALL
# OrderID
# 536370                                   0                               0
# 536852                                   0                               0
# 536974                                   0                               0
# 537065                                   0                               0
# 537463                                   0                               0
#
# [5 rows x 1562 columns]

# %% [markdown]
# # Step 4: Running the Apriori Algorithm

# %%
# !pip install mlxtend
# Out:
# Collecting mlxtend
#   Downloading mlxtend-0.23.1-py3-none-any.whl.metadata (7.3 kB)
# Requirement already satisfied: scipy>=1.2.1 in /opt/anaconda3/lib/python3.12/site-packages (from mlxtend) (1.13.1)
# Requirement already satisfied: numpy>=1.16.2 in /opt/anaconda3/lib/python3.12/site-packages (from mlxtend) (1.26.4)
# Requirement already satisfied: pandas>=0.24.2 in /opt/anaconda3/lib/python3.12/site-packages (from mlxtend) (2.2.2)
# Requirement already satisfied: scikit-learn>=1.0.2 in /opt/anaconda3/lib/python3.12/site-packages (from mlxtend) (1.4.2)
# Requirement already satisfied: matplotlib>=3.0.0 in /opt/anaconda3/lib/python3.12/site-packages (from mlxtend) (3.8.4)
# Requirement already satisfied: joblib>=0.13.2 in /opt/anaconda3/lib/python3.12/site-packages (from mlxtend) (1.4.2)
# Requirement already satisfied: contourpy>=1.0.1 in /opt/anaconda3/lib/python3.12/site-packages (from matplotlib>=3.0.0->mlxtend) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in /opt/anaconda3/lib/python3.12/site-packages (from matplotlib>=3.0.0->mlxtend) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/anaconda3/lib/python3.12/site-packages (from matplotlib>=3.0.0->mlxtend) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /opt/anaconda3/lib/python3.12/site-packages (from matplotlib>=3.0.0->mlxtend) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in /opt/anaconda3/lib/python3.12/site-packages (from matplotlib>=3.0.0->mlxtend) (23.2)
# Requirement already satisfied: pillow>=8 in /opt/anaconda3/lib/python3.12/site-packages (from matplotlib>=3.0.0->mlxtend) (10.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /opt/anaconda3/lib/python3.12/site-packages (from matplotlib>=3.0.0->mlxtend) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in /opt/anaconda3/lib/python3.12/site-packages (from matplotlib>=3.0.0->mlxtend) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /opt/anaconda3/lib/python3.12/site-packages (from pandas>=0.24.2->mlxtend) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in /opt/anaconda3/lib/python3.12/site-packages (from pandas>=0.24.2->mlxtend) (2023.3)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /opt/anaconda3/lib/python3.12/site-packages (from scikit-learn>=1.0.2->mlxtend) (2.2.0)
# Requirement already satisfied: six>=1.5 in /opt/anaconda3/lib/python3.12/site-packages (from python-dateutil>=2.7->matplotlib>=3.0.0->mlxtend) (1.16.0)
# Downloading mlxtend-0.23.1-py3-none-any.whl (1.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 1.7 MB/s eta 0:00:0000:0100:010m
# Installing collected packages: mlxtend
# Successfully installed mlxtend-0.23.1

# %%
from mlxtend.frequent_patterns import apriori, association_rules

# Convert DataFrame values to boolean for compatibility
df_grouped = df_grouped.astype(bool)

# Set minimum support threshold for the Apriori algorithm
min_support = 0.05  # Example: 5% minimum support threshold

# Apply the Apriori algorithm to generate frequent itemsets
frequent_itemsets = apriori(df_grouped, min_support=min_support, use_colnames=True)

# Generate association rules
rules = association_rules(frequent_itemsets, metric="lift", min_threshold=1)

# Show the generated frequent itemsets
print(frequent_itemsets)

# Show the generated association rules
print(rules)
# Out:
#      support                                           itemsets
# 0   0.063492                      (4 TRADITIONAL SPINNING TOPS)
# 1   0.088435                       (ALARM CLOCK BAKELIKE GREEN)
# 2   0.090703                        (ALARM CLOCK BAKELIKE PINK)
# 3   0.083900                        (ALARM CLOCK BAKELIKE RED )
# 4   0.061224                       (ASSORTED COLOUR MINI CASES)
# ..       ...                                                ...
# 79  0.090703  (SET6 RED SPOTTY PAPER PLATES, SET20 RED RETRO...
# 80  0.108844  (SET6 RED SPOTTY PAPER PLATES, SET6 RED SPOTTY...
# 81  0.056689  (ALARM CLOCK BAKELIKE PINK, ALARM CLOCK BAKELI...
# 82  0.061224  (PLASTERS IN TIN WOODLAND ANIMALS, PLASTERS IN...
# 83  0.088435  (SET6 RED SPOTTY PAPER PLATES, SET6 RED SPOTTY...
#
# [84 rows x 2 columns]
#                                           antecedents  \
# 0                         (ALARM CLOCK BAKELIKE PINK)
# 1                        (ALARM CLOCK BAKELIKE GREEN)
# 2                         (ALARM CLOCK BAKELIKE RED )
# 3                        (ALARM CLOCK BAKELIKE GREEN)
# 4                         (ALARM CLOCK BAKELIKE PINK)
# 5                         (ALARM CLOCK BAKELIKE RED )
# 6                     (CHILDRENS CUTLERY DOLLY GIRL )
# 7                       (CHILDRENS CUTLERY SPACEBOY )
# 8                               (SPACEBOY LUNCH BOX )
# 9                              (DOLLY GIRL LUNCH BOX)
# 10                          (LUNCH BAG RED RETROSPOT)
# 11                           (LUNCH BAG APPLE DESIGN)
# 12                       (LUNCH BAG SPACEBOY DESIGN )
# 13                           (LUNCH BAG APPLE DESIGN)
# 14                       (LUNCH BAG SPACEBOY DESIGN )
# 15                          (LUNCH BAG RED RETROSPOT)
# 16                       (LUNCH BAG SPACEBOY DESIGN )
# 17                               (LUNCH BAG WOODLAND)
# 18                (STRAWBERRY LUNCH BOX WITH CUTLERY)
# 19                (LUNCH BOX WITH CUTLERY RETROSPOT )
# 20                   (PLASTERS IN TIN CIRCUS PARADE )
# 21                         (PLASTERS IN TIN SPACEBOY)
# 22                   (PLASTERS IN TIN CIRCUS PARADE )
# 23                        (PLASTERS IN TIN STRONGMAN)
# 24                 (PLASTERS IN TIN WOODLAND ANIMALS)
# 25                   (PLASTERS IN TIN CIRCUS PARADE )
# 26                 (PLASTERS IN TIN WOODLAND ANIMALS)
# 27                         (PLASTERS IN TIN SPACEBOY)
# 28              (ROUND SNACK BOXES SET OF4 WOODLAND )
# 29               (ROUND SNACK BOXES SET OF 4 FRUITS )
# 30                       (SET6 RED SPOTTY PAPER CUPS)
# 31               (SET20 RED RETROSPOT PAPER NAPKINS )
# 32                     (SET6 RED SPOTTY PAPER PLATES)
# 33               (SET20 RED RETROSPOT PAPER NAPKINS )
# 34                     (SET6 RED SPOTTY PAPER PLATES)
# 35                       (SET6 RED SPOTTY PAPER CUPS)
# 36  (ALARM CLOCK BAKELIKE PINK, ALARM CLOCK BAKELI...
# 37  (ALARM CLOCK BAKELIKE PINK, ALARM CLOCK BAKELI...
# 38  (ALARM CLOCK BAKELIKE RED , ALARM CLOCK BAKELI...
# 39                        (ALARM CLOCK BAKELIKE PINK)
# 40                        (ALARM CLOCK BAKELIKE RED )
# 41                       (ALARM CLOCK BAKELIKE GREEN)
# 42  (PLASTERS IN TIN WOODLAND ANIMALS, PLASTERS IN...
# 43  (PLASTERS IN TIN WOODLAND ANIMALS, PLASTERS IN...
# 44  (PLASTERS IN TIN CIRCUS PARADE , PLASTERS IN T...
# 45                 (PLASTERS IN TIN WOODLAND ANIMALS)
# 46                   (PLASTERS IN TIN CIRCUS PARADE )
# 47                         (PLASTERS IN TIN SPACEBOY)
# 48  (SET6 RED SPOTTY PAPER PLATES, SET6 RED SPOTTY...
# 49  (SET6 RED SPOTTY PAPER PLATES, SET20 RED RETRO...
# 50  (SET6 RED SPOTTY PAPER CUPS, SET20 RED RETROSP...
# 51                     (SET6 RED SPOTTY PAPER PLATES)
# 52                       (SET6 RED SPOTTY PAPER CUPS)
# 53               (SET20 RED RETROSPOT PAPER NAPKINS )
#
#                                           consequents  antecedent support  \
# 0                        (ALARM CLOCK BAKELIKE GREEN)            0.090703
# 1                         (ALARM CLOCK BAKELIKE PINK)            0.088435
# 2                        (ALARM CLOCK BAKELIKE GREEN)            0.083900
# 3                         (ALARM CLOCK BAKELIKE RED )            0.088435
# 4                         (ALARM CLOCK BAKELIKE RED )            0.090703
# 5                         (ALARM CLOCK BAKELIKE PINK)            0.083900
# 6                       (CHILDRENS CUTLERY SPACEBOY )            0.065760
# 7                     (CHILDRENS CUTLERY DOLLY GIRL )            0.061224
# 8                              (DOLLY GIRL LUNCH BOX)            0.111111
# 9                               (SPACEBOY LUNCH BOX )            0.090703
# 10                           (LUNCH BAG APPLE DESIGN)            0.138322
# 11                          (LUNCH BAG RED RETROSPOT)            0.113379
# 12                           (LUNCH BAG APPLE DESIGN)            0.108844
# 13                       (LUNCH BAG SPACEBOY DESIGN )            0.113379
# 14                          (LUNCH BAG RED RETROSPOT)            0.108844
# 15                       (LUNCH BAG SPACEBOY DESIGN )            0.138322
# 16                               (LUNCH BAG WOODLAND)            0.108844
# 17                       (LUNCH BAG SPACEBOY DESIGN )            0.106576
# 18                (LUNCH BOX WITH CUTLERY RETROSPOT )            0.108844
# 19                (STRAWBERRY LUNCH BOX WITH CUTLERY)            0.129252
# 20                         (PLASTERS IN TIN SPACEBOY)            0.154195
# 21                   (PLASTERS IN TIN CIRCUS PARADE )            0.124717
# 22                        (PLASTERS IN TIN STRONGMAN)            0.154195
# 23                   (PLASTERS IN TIN CIRCUS PARADE )            0.072562
# 24                   (PLASTERS IN TIN CIRCUS PARADE )            0.151927
# 25                 (PLASTERS IN TIN WOODLAND ANIMALS)            0.154195
# 26                         (PLASTERS IN TIN SPACEBOY)            0.151927
# 27                 (PLASTERS IN TIN WOODLAND ANIMALS)            0.124717
# 28               (ROUND SNACK BOXES SET OF 4 FRUITS )            0.145125
# 29              (ROUND SNACK BOXES SET OF4 WOODLAND )            0.097506
# 30               (SET20 RED RETROSPOT PAPER NAPKINS )            0.122449
# 31                       (SET6 RED SPOTTY PAPER CUPS)            0.117914
# 32               (SET20 RED RETROSPOT PAPER NAPKINS )            0.113379
# 33                     (SET6 RED SPOTTY PAPER PLATES)            0.117914
# 34                       (SET6 RED SPOTTY PAPER CUPS)            0.113379
# 35                     (SET6 RED SPOTTY PAPER PLATES)            0.122449
# 36                       (ALARM CLOCK BAKELIKE GREEN)            0.065760
# 37                        (ALARM CLOCK BAKELIKE RED )            0.065760
# 38                        (ALARM CLOCK BAKELIKE PINK)            0.070295
# 39  (ALARM CLOCK BAKELIKE RED , ALARM CLOCK BAKELI...            0.090703
# 40  (ALARM CLOCK BAKELIKE PINK, ALARM CLOCK BAKELI...            0.083900
# 41  (ALARM CLOCK BAKELIKE PINK, ALARM CLOCK BAKELI...            0.088435
# 42                         (PLASTERS IN TIN SPACEBOY)            0.090703
# 43                   (PLASTERS IN TIN CIRCUS PARADE )            0.092971
# 44                 (PLASTERS IN TIN WOODLAND ANIMALS)            0.081633
# 45  (PLASTERS IN TIN CIRCUS PARADE , PLASTERS IN T...            0.151927
# 46  (PLASTERS IN TIN WOODLAND ANIMALS, PLASTERS IN...            0.154195
# 47  (PLASTERS IN TIN WOODLAND ANIMALS, PLASTERS IN...            0.124717
# 48               (SET20 RED RETROSPOT PAPER NAPKINS )            0.108844
# 49                       (SET6 RED SPOTTY PAPER CUPS)            0.090703
# 50                     (SET6 RED SPOTTY PAPER PLATES)            0.090703
# 51  (SET6 RED SPOTTY PAPER CUPS, SET20 RED RETROSP...            0.113379
# 52  (SET6 RED SPOTTY PAPER PLATES, SET20 RED RETRO...            0.122449
# 53  (SET6 RED SPOTTY PAPER PLATES, SET6 RED SPOTTY...            0.117914
#
#     consequent support   support  confidence       lift  leverage  conviction  \
# 0             0.088435  0.065760    0.725000   8.198077  0.057738    3.314780
# 1             0.090703  0.065760    0.743590   8.198077  0.057738    3.546259
# 2             0.088435  0.070295    0.837838   9.474012  0.062875    5.621315
# 3             0.083900  0.070295    0.794872   9.474012  0.062875    4.465986
# 4             0.083900  0.065760    0.725000   8.641216  0.058150    3.331272
# 5             0.090703  0.065760    0.783784   8.641216  0.058150    4.205499
# 6             0.061224  0.056689    0.862069  14.080460  0.052663    6.806122
# 7             0.065760  0.056689    0.925926  14.080460  0.052663   12.612245
# 8             0.090703  0.063492    0.571429   6.300000  0.053414    2.121693
# 9             0.111111  0.063492    0.700000   6.300000  0.053414    2.962963
# 10            0.113379  0.058957    0.426230   3.759344  0.043274    1.545254
# 11            0.138322  0.058957    0.520000   3.759344  0.043274    1.795163
# 12            0.113379  0.058957    0.541667   4.777500  0.046616    1.934447
# 13            0.108844  0.058957    0.520000   4.777500  0.046616    1.856576
# 14            0.138322  0.058957    0.541667   3.915984  0.043901    1.880025
# 15            0.108844  0.058957    0.426230   3.915984  0.043901    1.553158
# 16            0.106576  0.058957    0.541667   5.082447  0.047357    1.949289
# 17            0.108844  0.058957    0.553191   5.082447  0.047357    1.994493
# 18            0.129252  0.056689    0.520833   4.029605  0.042621    1.817214
# 19            0.108844  0.056689    0.438596   4.029605  0.042621    1.587372
# 20            0.124717  0.081633    0.529412   4.244920  0.062402    1.859977
# 21            0.154195  0.081633    0.654545   4.244920  0.062402    2.448383
# 22            0.072562  0.052154    0.338235   4.661305  0.040965    1.401461
# 23            0.154195  0.052154    0.718750   4.661305  0.040965    3.007307
# 24            0.154195  0.090703    0.597015   3.871817  0.067276    2.098849
# 25            0.151927  0.090703    0.588235   3.871817  0.067276    2.059605
# 26            0.124717  0.092971    0.611940   4.906649  0.074023    2.255538
# 27            0.151927  0.092971    0.745455   4.906649  0.074023    3.331714
# 28            0.097506  0.056689    0.390625   4.006177  0.042539    1.481016
# 29            0.145125  0.056689    0.581395   4.006177  0.042539    2.042202
# 30            0.117914  0.090703    0.740741   6.282051  0.076265    3.402332
# 31            0.122449  0.090703    0.769231   6.282051  0.076265    3.802721
# 32            0.117914  0.090703    0.800000   6.784615  0.077334    4.410431
# 33            0.113379  0.090703    0.769231   6.784615  0.077334    3.842026
# 34            0.122449  0.108844    0.960000   7.840000  0.094960   21.938776
# 35            0.113379  0.108844    0.888889   7.840000  0.094960    7.979592
# 36            0.088435  0.056689    0.862069   9.748011  0.050874    6.608844
# 37            0.083900  0.056689    0.862069  10.274930  0.051172    6.641723
# 38            0.090703  0.056689    0.806452   8.891129  0.050313    4.698035
# 39            0.070295  0.056689    0.625000   8.891129  0.050313    2.479214
# 40            0.065760  0.056689    0.675676  10.274930  0.051172    2.880574
# 41            0.065760  0.056689    0.641026   9.748011  0.050874    2.602527
# 42            0.124717  0.061224    0.675000   5.412273  0.049912    2.693180
# 43            0.154195  0.061224    0.658537   4.270803  0.046889    2.477000
# 44            0.151927  0.061224    0.750000   4.936567  0.048822    3.392290
# 45            0.081633  0.061224    0.402985   4.936567  0.048822    1.538265
# 46            0.092971  0.061224    0.397059   4.270803  0.046889    1.504342
# 47            0.090703  0.061224    0.490909   5.412273  0.049912    1.786119
# 48            0.117914  0.088435    0.812500   6.890625  0.075601    4.704460
# 49            0.122449  0.088435    0.975000   7.962500  0.077329   35.102041
# 50            0.113379  0.088435    0.975000   8.599500  0.078152   35.464853
# 51            0.090703  0.088435    0.780000   8.599500  0.078152    4.133168
# 52            0.090703  0.088435    0.722222   7.962500  0.077329    3.273469
# 53            0.108844  0.088435    0.750000   6.890625  0.075601    3.564626
#
#     zhangs_metric
# 0        0.965603
# 1        0.963201
# 2        0.976365
# 3        0.981223
# 4        0.972483
# 5        0.965261
# 6        0.994369
# 7        0.989565
# 8        0.946429
# 9        0.925187
# 10       0.851822
# 11       0.827858
# 12       0.887258
# 13       0.891796
# 14       0.835584
# 15       0.864170
# 16       0.901351
# 17       0.899063
# 18       0.843664
# 19       0.863437
# 20       0.903783
# 21       0.873345
# 22       0.928663
# 23       0.846923
# 24       0.874599
# 25       0.876944
# 26       0.938829
# 27       0.909642
# 28       0.877772
# 29       0.831457
# 30       0.958140
# 31       0.953213
# 32       0.961637
# 33       0.966581
# 34       0.984015
# 35       0.994186
# 36       0.960583
# 37       0.966214
# 38       0.954634
# 39       0.976060
# 40       0.985347
# 41       0.984478
# 42       0.896555
# 43       0.844352
# 44       0.868313
# 45       0.940285
# 46       0.905471
# 47       0.931395
# 48       0.959288
# 49       0.961634
# 50       0.971865
# 51       0.996721
# 52       0.996422
# 53       0.969152

# %% [markdown]
# # Step 5: Extract Support, Lift, and Confidence for Top 3 Rules

# %%
# Sort rules by confidence and extract the top 3 rules
top_3_rules = rules.sort_values('confidence', ascending=False).head(3)

# Print the top 3 rules with support, confidence, and lift
print(top_3_rules[['antecedents', 'consequents', 'support', 'confidence', 'lift']])

# You can also save the top 3 rules to a CSV if needed
top_3_rules[['antecedents', 'consequents', 'support', 'confidence', 'lift']].to_csv('top_3_rules.csv', index=False)
# Out:
#                                           antecedents  \
# 49  (SET6 RED SPOTTY PAPER PLATES, SET20 RED RETRO...
# 50  (SET6 RED SPOTTY PAPER CUPS, SET20 RED RETROSP...
# 34                     (SET6 RED SPOTTY PAPER PLATES)
#
#                        consequents   support  confidence    lift
# 49    (SET6 RED SPOTTY PAPER CUPS)  0.088435       0.975  7.9625
# 50  (SET6 RED SPOTTY PAPER PLATES)  0.088435       0.975  8.5995
# 34    (SET6 RED SPOTTY PAPER CUPS)  0.108844       0.960  7.8400
